# %% [markdown]
# <a href="https://colab.research.google.com/github/oakthyago/NLP_study_one/blob/main/BB_corpora_analiys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Using Kaggle API to import the dataset saving drive space**

# %%
from google.colab import files
import os
import shutil

# Upload kaggle.json
uploaded = files.upload()

# Move kaggle.json to the .kaggle directory
os.makedirs('/root/.kaggle', exist_ok=True)
shutil.move('kaggle.json', '/root/.kaggle/kaggle.json')

# Set permissions
# !chmod 600 /root/.kaggle/kaggle.json

# Verify setup
# !kaggle datasets list
# Out:
#      <input type="file" id="files-e8bc550d-cb79-439c-9803-6d6157b08240" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8bc550d-cb79-439c-9803-6d6157b08240">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: kaggle datasets download -d oakthyago/bbrc-brazilian-banking-regulation-corpora unzi

# !kaggle datasets download -d oakthyago/bbrc-brazilian-banking-regulation-corpora
# !unzip bbrc-brazilian-banking-regulation-corpora.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/oakthyago/bbrc-brazilian-banking-regulation-corpora
# License(s): MIT
# ...
#  99% 327M/329M [00:14<00:00, 24.2MB/s]
# 100% 329M/329M [00:14<00:00, 23.0MB/s]
# Archive:  bbrc-brazilian-banking-regulation-corpora.zip
#   inflating: BBRC_Brazilian_Banking_Regulation_Corpora.csv
#   inflating: README.md
#   inflating: gitattributes

# %%
import pandas as pd

df = pd.read_csv('/content/BBRC_Brazilian_Banking_Regulation_Corpora.csv', sep=';')

# %%
df.head()
# Out:
#    class department  entry_date  general_id normative_identifier  \
# 0      1        usi  2020-12-23        2128                36560
# 1      1        usi  2020-12-28        2129                36569
# 2      1        usi  2020-12-22        2130                36554
# 3      1        usi  2020-12-23        2131                 4880
# 4      1        usi  2020-12-23        2132            1125/2020
#
#   publication_date regulatory_authority  \
# 0       2020-12-23                BACEN
# 1       2020-12-28                BACEN
# 2       2020-12-22                BACEN
# 3       2020-12-23                BACEN
# 4       2020-12-22                BACEN
#
#                                              subject  subject_length  \
# 0  Divulga nome aprovado de pessoas eleitas/nomea...             167
# 1  Divulga nome aprovado de pessoas eleitas/nomea...             167
# 2  Divulga comunicado do Grupo de Ação Financeira...             120
# ...

# %%
df.text[0]
# Out:
# 'Divulgamos o nome aprovado de pessoas eleitas/nomeadas para cargos de órgãos estatutários ou contratuais de instituições financeiras, administradoras de consórcio e demais sociedades autorizadas a funcionar pelo Banco Central do Brasil: Processo: 183397.     Data do despacho: 22.12.2020. Instituição: Midway S.A. - Crédito, Financiamento e Investimento (CNPJ 09.464.032). Ato societário: Assembleia Geral Extraordinária de 6.11.2020. Órgão estatutário: Diretoria. Nome: Silvana Lavacca Arcuri (CPF 136.849.698-93).                                   José Reynaldo de Almeida Furlani              Chefe do Departamento de Organização do Sistema Financeiro\r\n'

# %%
# prompt: (df['class'] == 0).sum()
# (df['class'] == 1).sum()

print(f"Number of rows with class 0: {(df['class'] == 0).sum()}")
print(f"Number of rows with class 1: {(df['class'] == 1).sum()}")
# Out:
# Number of rows with class 0: 54018
# Number of rows with class 1: 7846
