# %% [markdown]
# <a href="https://colab.research.google.com/github/oakthyago/Alura/blob/main/Numpy_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.loadtxt('/content/apples_ts.csv',delimiter =',',usecols=np.arange(1,88,1))
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
dado =np.loadtxt('/content/apples_ts.csv',delimiter =',',usecols=np.arange(1,88,1))

# %%
dado_transposto= dado.T

# %%
datas = dado_transposto[:,0]

# %%
precos = dado_transposto[:,1:]

# %%
  precos
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,  66.06,  61.27,  72.91],
#        [ 80.8 ,  51.59,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
# ...

# %%
# prompt: import matplot lib

import matplotlib.pyplot as plt

# Assuming 'dado_transposto', 'datas', and 'precos' are defined from the previous code
datas = np.arange(1,88)
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.plot(datas, precos) #Example plot, customize as per requirement.
plt.xlabel("Dates")
plt.ylabel("Prices")
plt.title("Apple Prices Over Time")
plt.grid(True)
plt.show()

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
# prompt: plot moscow's

import matplotlib.pyplot as plt

# Assuming 'datas', 'Moscow', 'Moscow_ano1', 'Moscow_ano2', 'Moscow_ano3', and 'Moscow_ano4' are defined

plt.figure(figsize=(10, 6))

plt.plot(datas[:12], Moscow_ano1, label='Year 1')
plt.plot(datas[12:24], Moscow_ano2, label='Year 2')
plt.plot(datas[24:36], Moscow_ano3, label='Year 3')
plt.plot(datas[36:48], Moscow_ano4, label='Year 4')

plt.xlabel("Time Period")
plt.ylabel("Moscow Prices")
plt.title("Moscow Prices Over Time (First Four Years)")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(np.arange(1,13), Moscow_ano1, label='Year 1') # Use np.arange to make the x-axis correct.
plt.plot(np.arange(1,13), Moscow_ano2, label='Year 2') # Use np.arange to make the x-axis correct.
plt.plot(np.arange(1,13), Moscow_ano3, label='Year 3') # Use np.arange to make the x-axis correct.
plt.plot(np.arange(1,13), Moscow_ano4, label='Year 4') # Use np.arange to make the x-axis correct.

plt.xlabel("Time Period")
plt.ylabel("Moscow Prices")
plt.title("Moscow Prices Over Time (First Four Years)")
plt.legend()
plt.grid(True)
plt.show()

# %%
np.allclose(Moscow_ano1, Moscow_ano4,0.11)
# Out:
# False

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 0

# %% [markdown]
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Continuando com o projeto das laranjas/toranjas agora você deve selecionar parte dos dados. As colunas que iremos avaliar são as de diâmetro e peso. Crie arrays específicos para guardar o diâmetro e peso da laranja e toranja. O diâmetro está na coluna zero e o peso na coluna 1. Os dados referentes a laranja vão até a linha 4999 e os referentes à toranja iniciam na linha 5000 do arquivo.
#
# Após fazer a seleção de dados, importe a biblioteca matplotlib e crie um gráfico para a laranja e para a toranja do peso pelo diâmetro.

# %%
diametro_laranja = dado[:5000,0]
diametro_toranja = dado[5000:,0]
peso_laranja = dado[:5000,1]
peso_toranja = dado[5000:,1]

# %%
plt.plot(diametro_laranja, peso_laranja)
plt.plot(diametro_toranja, peso_toranja)

# %%
# prompt: plot a and b with laranjas

import matplotlib.pyplot as plt

# Assuming 'diametro_laranja', 'peso_laranja', 'diametro_toranja', 'peso_toranja', 'a', and 'b' are defined from the previous code

plt.figure(figsize=(10, 6))

# Plot laranja (orange)
plt.plot(diametro_laranja, peso_laranja, label='Laranja', marker='o', linestyle='-')

# Plot toranja (grapefruit)
plt.plot(diametro_toranja, peso_toranja, label='Toranja', marker='s', linestyle='-')

# Plot the line of best fit for laranjas
plt.plot(diametro_laranja, a*diametro_laranja + b, color='red', label='Regressão Linear (Laranjas)')


plt.xlabel("Diâmetro")
plt.ylabel("Peso")
plt.title("Diâmetro vs. Peso de Laranjas e Toranjas")
plt.legend()
plt.grid(True)
plt.show()

# %%
# prompt: coef = np.random.choice(low= 0.10,high=0.9, size=100, replace=False)
# unique_random_numbers
# # To generate unique random integers, you can use np.random.choice without replacement.
# coef = np.random.choice(low= 0.10,high=0.9, size=100, replace=False)
# unique_random_numbers

import numpy as np

# To generate unique random numbers between 0.1 and 0.9, you can use np.random.uniform.
# np.random.choice with replace=False doesn't work correctly when the low and high are floats.
coef = np.random.uniform(low=0.1, high=0.9, size=100)

#Check for uniqueness (optional, you'll likely get some duplicates with floating points)
coef
# Out:
# array([0.6240935 , 0.53951497, 0.51282477, 0.6644497 , 0.16047682,
#        0.24072687, 0.17029769, 0.68791933, 0.74303577, 0.19057537,
#        0.74625832, 0.63650875, 0.5895958 , 0.23048186, 0.35101042,
#        0.31117127, 0.22327608, 0.48076165, 0.7112888 , 0.55919644,
#        0.84110444, 0.72152132, 0.7035486 , 0.35119672, 0.83737033,
#        0.5100435 , 0.75239888, 0.87163323, 0.82823061, 0.2739676 ,
#        0.2715791 , 0.4585998 , 0.67197293, 0.45133404, 0.19646999,
#        0.4676651 , 0.43005733, 0.78713352, 0.52983063, 0.8269963 ,
#        0.56369344, 0.55660953, 0.28506819, 0.55861483, 0.65640135,
#        0.28166445, 0.66664263, 0.66107555, 0.75444883, 0.1963794 ,
#        0.45346989, 0.31927787, 0.37119897, 0.4585186 , 0.8442574 ,
#        0.86249393, 0.35194214, 0.39079958, 0.58097497, 0.60271277,
#        0.77804255, 0.50144498, 0.78751057, 0.31562957, 0.33233055,
#        0.67202274, 0.16576371, 0.17924778, 0.1194925 , 0.13947129,
# ...

# %%
# prompt: coef low to high inside the array

# Sort the 'coef' array from low to high
coef_sorted = np.sort(coef)
X = datas
# Print the sorted array
coef_sorted
norma = np.array([])
for i in range(100):
  norma = np.append(norma,np.linalg.norm(Moscow -(coef_sorted[i]*X+b)))
norma
# Out:
# array([872.05200196, 871.64917154, 870.29406273, 867.25857777,
#        859.74469426, 859.73507567, 858.75660597, 849.83908081,
#        847.59815424, 846.91045598, 845.67751352, 841.88929968,
#        837.10084724, 834.64999778, 834.61175697, 833.0708138 ,
#        826.94800274, 823.31644217, 820.28696841, 817.29041259,
#        815.98483272, 812.01135323, 804.94626878, 804.35521489,
#        803.60784888, 803.06628606, 802.06853778, 798.85570983,
#        797.43608061, 786.57317316, 784.7221844 , 784.70098552,
#        783.2084501 , 777.79986923, 771.29565935, 770.90815866,
#        770.07943045, 770.00255024, 769.69496977, 761.76248498,
#        755.54313633, 753.71547107, 743.34561884, 737.68398888,
#        729.92356322, 729.04526972, 728.89720597, 728.18008389,
#        726.13644425, 726.10359331, 722.4394218 , 717.15795487,
#        708.84685717, 705.4027837 , 704.2901787 , 697.5025116 ,
#        693.64905368, 686.8686769 , 686.38127787, 686.07513744,
# ...

# %%
# prompt: norma.min position value

# Find the index of the minimum value in the 'norma' array
min_index = np.argmin(norma)

# Print the minimum value and its corresponding position
print("Minimum value:", norma[min_index])
print("Position of minimum value:", min_index)
coef[99]
# Out:
# Minimum value: 566.5250204861204
# Position of minimum value: 99
# 0.3490025257964595
